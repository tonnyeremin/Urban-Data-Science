# %% [markdown]
# # Prague Pedestrian Accessibility for Children (age 10-16). Part 3
# ## Modelling

# %%
# !conda install -c conda-forge basemap

# %%
# !conda install -c conda-forge pandana

# %%
from IPython.display import display_html
display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

# %%
# !conda update --all #update all other package. Restart kernel if needed
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pyrsistent-0.15.4          |   py36h7b6447c_0          92 KB
#     pytables-3.4.4             |   py36ha205bf6_0         1.5 MB
#     pycurl-7.43.0.2            |   py36hb7f436b_0          60 KB
#     nltk-3.4.5                 |           py36_0         2.1 MB
#     openssl-1.0.2t             |       h7b6447c_1         3.1 MB
#     zipp-0.6.0                 |             py_0           9 KB
#     scikit-learn-0.21.3        |   py36hd81dba3_0         6.8 MB
#     spyder-kernels-0.5.2       |           py36_0          69 KB
#     jinja2-2.10.3              |             py_0          95 KB
#     tensorflow-base-2.0.0      |eigen_py36h4ed9498_0        68.9 MB
#     lazy-object-proxy-1.4.2    |   py36h7b6447c_0          30 KB
#     libspatialindex-1.8.5      |       h20b78c2_2         666 KB
#     mock-3.0.5                 |           py36_0          47 KB
#     protobuf-3.9.2             |   py36he6710b0_0         701 KB
#     numpy-base-1.17.2          |   py36hde5b4d6_0         5.3 MB
#     freetds-1.00.97            |       hc365091_0         2.4 MB
#     bitarray-1.0.1             |   py36h7b6447c_0          60 KB
#     werkzeug-0.16.0            |             py_0         255 KB
#     pytest-doctestplus-0.4.0   |             py_0          18 KB
#     wrapt-1.11.2               |   py36h7b6447c_0          48 KB
#     kealib-1.4.7               |       h77bc034_6         170 KB
#     freexl-1.0.5               |       h14c3975_0          44 KB
#     libpq-10.5                 |       h1ad7b7a_0         2.7 MB
#     nbconvert-5.6.0            |           py36_1         494 KB
#     markupsafe-1.1.1           |   py36h7b6447c_0          29 KB
#     libevent-2.1.8             |       h93c0eb6_0         1.4 MB
#     dask-core-2.6.0            |             py_0         578 KB
#     tblib-1.4.0                |             py_0          14 KB
#     pathlib2-2.3.5             |           py36_0          37 KB
#     basemap-1.2.0              |   py36h705c2d8_0        15.2 MB
#     ipykernel-5.1.3            |   py36h39e3cac_0         167 KB
#     contextlib2-0.6.0          |             py_0          16 KB
#     ipython-7.9.0              |   py36h39e3cac_0         1.1 MB
#     plotly-4.1.1               |             py_0         4.0 MB
#     opt_einsum-3.1.0           |             py_0          54 KB
#     markdown-3.1.1             |           py36_0         113 KB
#     pytest-openfiles-0.4.0     |             py_0          10 KB
#     mkl_fft-1.0.14             |   py36ha843d7b_0         173 KB
#     libspatialite-4.3.0a       |      he475c7f_19         3.1 MB
#     py-1.8.0                   |             py_0          66 KB
#     typed-ast-1.4.0            |   py36h7b6447c_0         208 KB
#     scikit-image-0.15.0        |   py36he6710b0_0        28.4 MB
#     cryptography-2.3.1         |   py36hc365091_0         585 KB
#     sphinxcontrib-htmlhelp-1.0.2|             py_0          28 KB
#     biopython-1.74             |   py36h7b6447c_0         2.5 MB
#     dbus-1.13.12               |       h746ee38_0         611 KB
#     packaging-19.2             |             py_0          30 KB
#     pcre-8.43                  |       he6710b0_0         260 KB
#     libprotobuf-3.9.2          |       hd408876_0         4.7 MB
#     hdf4-4.2.13                |       h3ca952b_2         916 KB
#     asn1crypto-1.2.0           |           py36_0         162 KB
#     rope-0.14.0                |             py_0         113 KB
#     cython-0.29.13             |   py36he6710b0_0         2.2 MB
#     pyflakes-2.1.1             |           py36_0         105 KB
#     hdf5-1.10.2                |       hba1933b_1         5.2 MB
#     poppler-data-0.4.9         |                0         3.5 MB
#     jupyter_core-4.6.0         |           py36_0          74 KB
#     scipy-1.3.1                |   py36h7c811a0_0        18.1 MB
#     attrs-19.3.0               |             py_0          39 KB
#     tqdm-4.36.1                |             py_0          50 KB
#     qt-5.9.6                   |       h8703b6f_2        87.1 MB
#     jdcal-1.4.1                |             py_0          11 KB
#     decorator-4.4.1            |             py_0          13 KB
#     ca-certificates-2019.10.16 |                0         131 KB
#     lxml-4.4.1                 |   py36hefd8a0e_0         1.6 MB
#     parso-0.5.1                |             py_0          68 KB
#     wurlitzer-1.0.3            |           py36_0          14 KB
#     pixman-0.38.0              |       h7b6447c_0         618 KB
#     secretstorage-3.1.1        |           py36_0          24 KB
#     snowballstemmer-2.0.0      |             py_0          58 KB
#     importlib_metadata-0.23    |           py36_0          43 KB
#     sphinxcontrib-devhelp-1.0.1|             py_0          23 KB
#     py-xgboost-0.90            |   py36he6710b0_1          77 KB
#     mkl_random-1.1.0           |   py36hd6b4f25_0         369 KB
#     qtpy-1.9.0                 |             py_0          39 KB
#     qtconsole-4.5.5            |             py_0          94 KB
#     notebook-6.0.1             |           py36_0         6.0 MB
#     xlsxwriter-1.2.2           |             py_0         106 KB
#     libkml-1.3.0               |       h590aaf7_4         633 KB
#     munch-2.3.2                |           py36_0          13 KB
#     pluggy-0.13.0              |           py36_0          31 KB
#     cloudpickle-1.2.2          |             py_0          29 KB
#     ipywidgets-7.5.1           |             py_0         107 KB
#     descartes-1.1.0            |             py_3           9 KB
#     numexpr-2.7.0              |   py36h9e4a6bb_0         196 KB
#     soupsieve-1.9.3            |           py36_0          60 KB
#     llvmlite-0.30.0            |   py36hd408876_0        17.7 MB
#     qtawesome-0.6.0            |             py_0         671 KB
#     numba-0.46.0               |   py36h962f231_0         3.2 MB
#     setuptools-41.6.0          |           py36_0         650 KB
#     toolz-0.10.0               |             py_0          50 KB
#     mkl-2019.4                 |              243       204.1 MB
#     isort-4.3.21               |           py36_0          68 KB
#     urllib3-1.24.2             |           py36_0         153 KB
#     sphinx-2.2.1               |             py_0         1.4 MB
#     bzip2-1.0.8                |       h7b6447c_0         105 KB
#     libssh2-1.8.0              |       h9cfc8f7_4         243 KB
#     beautifulsoup4-4.8.1       |           py36_0         153 KB
#     pytest-5.0.1               |           py36_0         353 KB
#     certifi-2019.9.11          |           py36_0         154 KB
#     tabulate-0.8.3             |           py36_0          39 KB
#     networkx-2.4               |             py_0         1.2 MB
#     json5-0.8.5                |             py_0          25 KB
#     python-3.6.6               |       h6e4f718_2        28.9 MB
#     cytoolz-0.10.0             |   py36h7b6447c_0         439 KB
#     itsdangerous-1.1.0         |             py_0          17 KB
#     alabaster-0.7.12           |             py_0          16 KB
#     astroid-2.3.2              |           py36_0         283 KB
#     astor-0.8.0                |           py36_0          45 KB
#     sqlite-3.30.1              |       h7b6447c_0         1.9 MB
#     matplotlib-3.1.1           |   py36h5429711_0         6.7 MB
#     numpydoc-0.9.1             |             py_0          31 KB
#     jeepney-0.4.1              |             py_0          21 KB
#     flask-cors-3.0.8           |             py_0          17 KB
#     pyparsing-2.4.2            |             py_0          61 KB
#     more-itertools-7.2.0       |           py36_0          99 KB
#     widgetsnbextension-3.5.1   |           py36_0         1.8 MB
#     filelock-3.0.12            |             py_0          12 KB
#     json-c-0.13.1              |       h1bed415_0          70 KB
#     prometheus_client-0.7.1    |             py_0          42 KB
#     giflib-5.1.4               |       h14c3975_1          78 KB
#     fiona-1.7.12               |   py36h3f37509_0         704 KB
#     h5py-2.8.0                 |   py36h989c5e5_3         1.1 MB
#     pyproj-1.9.5.1             |   py36h7b21b82_1          64 KB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     cffi-1.13.1                |   py36h2e261b9_0         224 KB
#     spyder-3.3.6               |           py36_0         2.5 MB
#     libnetcdf-4.6.1            |       h10edf3e_1         1.3 MB
#     grpcio-1.14.1              |   py36h9ba97e2_0         1.0 MB
#     keras-applications-1.0.8   |             py_0          33 KB
#     jedi-0.15.1                |           py36_0         721 KB
#     colorama-0.4.1             |             py_0          17 KB
#     jmespath-0.9.4             |             py_0          22 KB
#     pbr-5.4.3                  |             py_0          78 KB
#     cligj-0.5.0                |           py36_0          12 KB
#     keras-preprocessing-1.1.0  |             py_1          36 KB
#     pip-19.3.1                 |           py36_0         1.9 MB
#     python-dateutil-2.8.0      |           py36_0         281 KB
#     heapdict-1.0.1             |             py_0           9 KB
#     krb5-1.16.1                |       hc83ff2d_6         1.4 MB
#     jupyterlab-1.1.4           |     pyhf63ae98_0        11.7 MB
#     pyzmq-18.1.0               |   py36he6710b0_0         520 KB
#     flask-1.1.1                |             py_0          73 KB
#     libgdal-2.2.4              |       h6f639c0_1        16.1 MB
#     glob2-0.7                  |             py_0          14 KB
#     tensorflow-estimator-2.0.0 |     pyh2649769_0         272 KB
#     boto3-1.9.234              |             py_0          91 KB
#     imagesize-1.1.0            |             py_0           8 KB
#     pyyaml-5.1.2               |   py36h7b6447c_0         189 KB
#     google-pasta-0.1.7         |             py_0          41 KB
#     prompt_toolkit-2.0.10      |             py_0         227 KB
#     anaconda-project-0.8.4     |             py_0         215 KB
#     absl-py-0.8.0              |           py36_0         161 KB
#     jupyter_client-5.3.4       |           py36_0         136 KB
#     wheel-0.33.6               |           py36_0          40 KB
#     proj4-5.0.1                |       h14c3975_0         7.0 MB
#     pyodbc-4.0.27              |   py36he6710b0_0          70 KB
#     mapclassify-2.0.1          |             py_0          26 KB
#     traitlets-4.3.3            |           py36_0         137 KB
#     openpyxl-3.0.0             |             py_0         157 KB
#     pexpect-4.7.0              |           py36_0          82 KB
#     sphinxcontrib-websupport-1.1.2|             py_0          35 KB
#     _low_priority-1.0          |                0         139 KB
#     dask-2.6.0                 |             py_0          12 KB
#     requests-2.22.0            |           py36_0          89 KB
#     statsmodels-0.10.1         |   py36hdd07704_0         9.6 MB
#     partd-1.0.0                |             py_0          19 KB
#     fastcache-1.1.0            |   py36h7b6447c_0          31 KB
#     pytest-remotedata-0.3.2    |           py36_0          15 KB
#     docutils-0.15.2            |           py36_0         742 KB
#     jsonschema-3.1.1           |           py36_0          92 KB
#     kiwisolver-1.1.0           |   py36he6710b0_0          90 KB
#     xerces-c-3.2.2             |       h780794e_0         3.2 MB
#     psycopg2-2.7.5             |   py36hb7f436b_0         294 KB
#     pywavelets-1.1.1           |   py36h7b6447c_0         4.4 MB
#     psutil-5.6.3               |   py36h7b6447c_0         328 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     geos-3.6.2                 |       heeff764_2         1.6 MB
#     rtree-0.8.3                |           py36_0          46 KB
#     boost-cpp-1.67.0           |       h14c3975_4          11 KB
#     numpy-1.17.2               |   py36haad9e8e_0           4 KB
#     pysocks-1.7.1              |           py36_0          30 KB
#     path.py-12.0.1             |             py_0          23 KB
#     imageio-2.6.1              |           py36_0         3.4 MB
#     pytz-2019.3                |             py_0         231 KB
#     sqlalchemy-1.3.10          |   py36h7b6447c_0         1.8 MB
#     geopandas-0.4.1            |             py_0         891 KB
#     pandas-0.25.2              |   py36he6710b0_0        11.4 MB
#     joblib-0.13.2              |           py36_0         365 KB
#     tornado-6.0.3              |   py36h7b6447c_0         643 KB
#     sympy-1.4                  |           py36_0         9.7 MB
#     bokeh-1.3.4                |           py36_0         4.0 MB
#     curl-7.61.0                |       h84994c4_0         141 KB
#     libxgboost-0.90            |       he6710b0_1         3.8 MB
#     click-plugins-1.1.1        |             py_0          11 KB
#     sphinxcontrib-serializinghtml-1.1.3|             py_0          24 KB
#     botocore-1.12.234          |             py_0         3.4 MB
#     terminado-0.8.2            |           py36_0          22 KB
#     dill-0.3.0                 |           py36_0         116 KB
#     gdal-2.2.2                 |   py36hc209d97_1         767 KB
#     s3transfer-0.2.1           |           py36_0          96 KB
#     jupyterlab_server-1.0.6    |             py_0          26 KB
#     intel-openmp-2019.4        |              243         876 KB
#     libarchive-3.3.2           |       hb43526a_6         1.5 MB
#     openjpeg-2.3.0             |       h05c96fa_1         456 KB
#     babel-2.7.0                |             py_0         5.8 MB
#     mkl-service-2.3.0          |   py36he904b0f_0         208 KB
#     libcurl-7.61.0             |       h1ad7b7a_0         494 KB
#     sphinxcontrib-applehelp-1.0.1|             py_0          29 KB
#     zict-1.0.0                 |             py_0          12 KB
#     shapely-1.6.4              |   py36h7ef4460_0         326 KB
#     pylint-2.4.3               |           py36_0         432 KB
#     sphinxcontrib-jsmath-1.0.1 |             py_0           8 KB
#     cx_oracle-7.2.2            |   py36h7b6447c_0         181 KB
#     fsspec-0.5.2               |             py_0          46 KB
#     pillow-6.2.0               |   py36h34e0f95_0         647 KB
#     distributed-2.6.0          |             py_0         393 KB
#     thrift-cpp-0.11.0          |       hc04171f_3         2.3 MB
#     sphinxcontrib-qthelp-1.0.2 |             py_0          26 KB
#     astropy-3.2.2              |   py36h7b6447c_0         7.1 MB
#     blosc-1.16.3               |       hd408876_0          82 KB
#     ------------------------------------------------------------
#                                            Total:       700.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     _low_priority:                 1.0-0
#     descartes:                     1.1.0-py_3
#     fsspec:                        0.5.2-py_0
#     google-pasta:                  0.1.7-py_0
#     joblib:                        0.13.2-py36_0
#     json5:                         0.8.5-py_0
#     mapclassify:                   2.0.1-py_0
#     opt_einsum:                    3.1.0-py_0
#     pyrsistent:                    0.15.4-py36h7b6447c_0
#     sphinxcontrib-applehelp:       1.0.1-py_0
#     sphinxcontrib-devhelp:         1.0.1-py_0
#     sphinxcontrib-htmlhelp:        1.0.2-py_0
#     sphinxcontrib-jsmath:          1.0.1-py_0
#     sphinxcontrib-qthelp:          1.0.2-py_0
#     sphinxcontrib-serializinghtml: 1.1.3-py_0
#     zipp:                          0.6.0-py_0
#
# The following packages will be UPDATED:
#
#     absl-py:                       0.7.0-py36_0                          --> 0.8.0-py36_0
#     alabaster:                     0.7.12-py36_0                         --> 0.7.12-py_0
#     anaconda-project:              0.8.2-py36_0                          --> 0.8.4-py_0
#     asn1crypto:                    0.24.0-py36_0                         --> 1.2.0-py36_0
#     astor:                         0.7.1-py36_0                          --> 0.8.0-py36_0
#     astroid:                       2.1.0-py36_0                          --> 2.3.2-py36_0
#     astropy:                       3.1.1-py36h7b6447c_0                  --> 3.2.2-py36h7b6447c_0
#     attrs:                         18.2.0-py36h28b3542_0                 --> 19.3.0-py_0
#     babel:                         2.6.0-py36_0                          --> 2.7.0-py_0
#     beautifulsoup4:                4.7.1-py36_1                          --> 4.8.1-py36_0
#     biopython:                     1.72-py36h04863e7_0                   --> 1.74-py36h7b6447c_0
#     bitarray:                      0.8.3-py36h14c3975_0                  --> 1.0.1-py36h7b6447c_0
#     blosc:                         1.15.0-hd408876_0                     --> 1.16.3-hd408876_0
#     bokeh:                         1.0.4-py36_0                          --> 1.3.4-py36_0
#     boto3:                         1.9.82-py_0                           --> 1.9.234-py_0
#     botocore:                      1.12.82-py_0                          --> 1.12.234-py_0
#     bzip2:                         1.0.7-h7b6447c_0                      --> 1.0.8-h7b6447c_0
#     ca-certificates:               2019.9.11-hecc5488_0      conda-forge --> 2019.10.16-0
#     certifi:                       2019.9.11-py36_0          conda-forge --> 2019.9.11-py36_0
#     cffi:                          1.11.5-py36he75722e_1                 --> 1.13.1-py36h2e261b9_0
#     click-plugins:                 1.1.1-py_0                conda-forge --> 1.1.1-py_0
#     cligj:                         0.5.0-py_0                conda-forge --> 0.5.0-py36_0
#     cloudpickle:                   0.7.0-py_0                            --> 1.2.2-py_0
#     colorama:                      0.4.1-py36_0                          --> 0.4.1-py_0
#     contextlib2:                   0.5.5-py36_0                          --> 0.6.0-py_0
#     cx_oracle:                     7.0.0-py36h7b6447c_0                  --> 7.2.2-py36h7b6447c_0
#     cython:                        0.29.5-py36he6710b0_0                 --> 0.29.13-py36he6710b0_0
#     cytoolz:                       0.9.0.1-py36h14c3975_1                --> 0.10.0-py36h7b6447c_0
#     dask:                          1.1.1-py_0                            --> 2.6.0-py_0
#     dask-core:                     1.1.1-py_0                            --> 2.6.0-py_0
#     dbus:                          1.13.6-h746ee38_0                     --> 1.13.12-h746ee38_0
#     decorator:                     4.3.2-py36_0                          --> 4.4.1-py_0
#     defusedxml:                    0.5.0-py36_1                          --> 0.6.0-py_0
#     dill:                          0.2.8.2-py36_0                        --> 0.3.0-py36_0
#     distributed:                   1.25.3-py36_0                         --> 2.6.0-py_0
#     docutils:                      0.14-py36_0                           --> 0.15.2-py36_0
#     fastcache:                     1.0.2-py36h14c3975_2                  --> 1.1.0-py36h7b6447c_0
#     filelock:                      3.0.10-py36_0                         --> 3.0.12-py_0
#     flask:                         1.0.2-py36_1                          --> 1.1.1-py_0
#     flask-cors:                    3.0.7-py36_0                          --> 3.0.8-py_0
#     freetds:                       1.00.97-h1ba5d50_0                    --> 1.00.97-hc365091_0
#     glob2:                         0.6-py36_1                            --> 0.7-py_0
#     hdf4:                          4.2.13-0                  conda-forge --> 4.2.13-h3ca952b_2
#     heapdict:                      1.0.0-py36_2                          --> 1.0.1-py_0
#     imageio:                       2.4.1-py36_0                          --> 2.6.1-py36_0
#     imagesize:                     1.1.0-py36_0                          --> 1.1.0-py_0
#     importlib_metadata:            0.7-py36_0                            --> 0.23-py36_0
#     intel-openmp:                  2019.1-144                            --> 2019.4-243
#     ipykernel:                     5.1.0-py36h39e3cac_0                  --> 5.1.3-py36h39e3cac_0
#     ipython:                       7.2.0-py36h39e3cac_0                  --> 7.9.0-py36h39e3cac_0
#     ipywidgets:                    7.4.2-py36_0                          --> 7.5.1-py_0
#     isort:                         4.3.4-py36_0                          --> 4.3.21-py36_0
#     itsdangerous:                  1.1.0-py36_0                          --> 1.1.0-py_0
#     jdcal:                         1.4-py36_0                            --> 1.4.1-py_0
#     jedi:                          0.13.2-py36_0                         --> 0.15.1-py36_0
#     jeepney:                       0.4-py36_0                            --> 0.4.1-py_0
#     jinja2:                        2.10-py36_0                           --> 2.10.3-py_0
#     jmespath:                      0.9.3-py36_0                          --> 0.9.4-py_0
#     jsonschema:                    2.6.0-py36_0                          --> 3.1.1-py36_0
#     jupyter_client:                5.2.4-py36_0                          --> 5.3.4-py36_0
#     jupyter_core:                  4.4.0-py36_0                          --> 4.6.0-py36_0
#     jupyterlab:                    0.35.3-py36_0                         --> 1.1.4-pyhf63ae98_0
#     jupyterlab_server:             0.2.0-py36_0                          --> 1.0.6-py_0
#     keras-applications:            1.0.6-py36_0                          --> 1.0.8-py_0
#     keras-preprocessing:           1.0.5-py36_0                          --> 1.1.0-py_1
#     kiwisolver:                    1.0.1-py36hf484d3e_0                  --> 1.1.0-py36he6710b0_0
#     lazy-object-proxy:             1.3.1-py36h14c3975_2                  --> 1.4.2-py36h7b6447c_0
#     libevent:                      2.1.8-h1ba5d50_0                      --> 2.1.8-h93c0eb6_0
#     libgcc-ng:                     8.2.0-hdf63c60_1                      --> 9.1.0-hdf63c60_0
#     libprotobuf:                   3.6.1-hd408876_0                      --> 3.9.2-hd408876_0
#     libssh2:                       1.8.0-h1ba5d50_4                      --> 1.8.0-h9cfc8f7_4
#     libstdcxx-ng:                  8.2.0-hdf63c60_1                      --> 9.1.0-hdf63c60_0
#     libxgboost:                    0.80-he6710b0_0                       --> 0.90-he6710b0_1
#     llvmlite:                      0.27.0-py36hd408876_0                 --> 0.30.0-py36hd408876_0
#     lxml:                          4.3.1-py36hefd8a0e_0                  --> 4.4.1-py36hefd8a0e_0
#     markdown:                      3.0.1-py36_0                          --> 3.1.1-py36_0
#     markupsafe:                    1.1.0-py36h7b6447c_0                  --> 1.1.1-py36h7b6447c_0
#     matplotlib:                    3.0.2-py36h5429711_0                  --> 3.1.1-py36h5429711_0
#     mkl:                           2019.1-144                            --> 2019.4-243
#     mkl-service:                   1.1.2-py36he904b0f_5                  --> 2.3.0-py36he904b0f_0
#     mkl_fft:                       1.0.10-py36ha843d7b_0                 --> 1.0.14-py36ha843d7b_0
#     mkl_random:                    1.0.2-py36hd81dba3_0                  --> 1.1.0-py36hd6b4f25_0
#     mock:                          2.0.0-py36_0                          --> 3.0.5-py36_0
#     more-itertools:                5.0.0-py36_0                          --> 7.2.0-py36_0
#     nbconvert:                     5.4.0-py36_1                          --> 5.6.0-py36_1
#     networkx:                      2.2-py36_1                            --> 2.4-py_0
#     nltk:                          3.4-py36_1                            --> 3.4.5-py36_0
#     notebook:                      5.7.8-py36_0                          --> 6.0.1-py36_0
#     numba:                         0.42.0-py36h962f231_0                 --> 0.46.0-py36h962f231_0
#     numexpr:                       2.6.9-py36h9e4a6bb_0                  --> 2.7.0-py36h9e4a6bb_0
#     numpy:                         1.15.4-py36h7e9f1db_0                 --> 1.17.2-py36haad9e8e_0
#     numpy-base:                    1.15.4-py36hde5b4d6_0                 --> 1.17.2-py36hde5b4d6_0
#     numpydoc:                      0.8.0-py36_0                          --> 0.9.1-py_0
#     openpyxl:                      2.6.0-py36_0                          --> 3.0.0-py_0
#     packaging:                     19.0-py36_0                           --> 19.2-py_0
#     pandas:                        0.24.1-py36he6710b0_0                 --> 0.25.2-py36he6710b0_0
#     parso:                         0.3.2-py36_0                          --> 0.5.1-py_0
#     partd:                         0.3.9-py36_0                          --> 1.0.0-py_0
#     path.py:                       11.5.0-py36_0                         --> 12.0.1-py_0
#     pathlib2:                      2.3.3-py36_0                          --> 2.3.5-py36_0
#     pbr:                           5.1.3-py_0                            --> 5.4.3-py_0
#     pcre:                          8.42-h439df22_0                       --> 8.43-he6710b0_0
#     pexpect:                       4.6.0-py36_0                          --> 4.7.0-py36_0
#     pillow:                        5.4.1-py36h34e0f95_0                  --> 6.2.0-py36h34e0f95_0
#     pip:                           19.1.1-py36_0                         --> 19.3.1-py36_0
#     pixman:                        0.36.0-h7b6447c_0                     --> 0.38.0-h7b6447c_0
#     plotly:                        3.6.1-py36_0                          --> 4.1.1-py_0
#     pluggy:                        0.8.1-py36_0                          --> 0.13.0-py36_0
#     prometheus_client:             0.5.0-py36_0                          --> 0.7.1-py_0
#     prompt_toolkit:                2.0.8-py_0                            --> 2.0.10-py_0
#     protobuf:                      3.6.1-py36he6710b0_0                  --> 3.9.2-py36he6710b0_0
#     psutil:                        5.5.0-py36h7b6447c_0                  --> 5.6.3-py36h7b6447c_0
#     py:                            1.7.0-py36_0                          --> 1.8.0-py_0
#     py-xgboost:                    0.80-py36he6710b0_0                   --> 0.90-py36he6710b0_1
#     pycurl:                        7.43.0.2-py36h1ba5d50_0               --> 7.43.0.2-py36hb7f436b_0
#     pyflakes:                      2.1.0-py36_0                          --> 2.1.1-py36_0
#     pygments:                      2.3.1-py36_0                          --> 2.4.2-py_0
#     pylint:                        2.2.2-py36_0                          --> 2.4.3-py36_0
#     pyodbc:                        4.0.25-py36he6710b0_0                 --> 4.0.27-py36he6710b0_0
#     pyparsing:                     2.3.1-py36_0                          --> 2.4.2-py_0
#     pysocks:                       1.6.8-py36_0                          --> 1.7.1-py36_0
#     pytables:                      3.4.4-py36h71ec239_0                  --> 3.4.4-py36ha205bf6_0
#     pytest:                        4.2.1-py36_0                          --> 5.0.1-py36_0
#     pytest-doctestplus:            0.2.0-py36_0                          --> 0.4.0-py_0
#     pytest-openfiles:              0.3.2-py36_0                          --> 0.4.0-py_0
#     pytest-remotedata:             0.3.1-py36_0                          --> 0.3.2-py36_0
#     python-dateutil:               2.7.5-py36_0                          --> 2.8.0-py36_0
#     pytz:                          2018.9-py36_0                         --> 2019.3-py_0
#     pywavelets:                    1.0.1-py36hdd07704_0                  --> 1.1.1-py36h7b6447c_0
#     pyyaml:                        3.13-py36h14c3975_0                   --> 5.1.2-py36h7b6447c_0
#     pyzmq:                         17.1.2-py36he6710b0_2                 --> 18.1.0-py36he6710b0_0
#     qtawesome:                     0.5.6-py_0                            --> 0.6.0-py_0
#     qtconsole:                     4.4.3-py36_0                          --> 4.5.5-py_0
#     qtpy:                          1.6.0-py_0                            --> 1.9.0-py_0
#     requests:                      2.21.0-py36_0                         --> 2.22.0-py36_0
#     rope:                          0.11.0-py_0                           --> 0.14.0-py_0
#     s3transfer:                    0.1.13-py36_0                         --> 0.2.1-py36_0
#     scikit-image:                  0.14.1-py36he6710b0_0                 --> 0.15.0-py36he6710b0_0
#     scikit-learn:                  0.20.3-py36hd81dba3_0                 --> 0.21.3-py36hd81dba3_0
#     scipy:                         1.2.0-py36h7c811a0_0                  --> 1.3.1-py36h7c811a0_0
#     secretstorage:                 3.1.0-py36_0                          --> 3.1.1-py36_0
#     setuptools:                    40.8.0-py36_0                         --> 41.6.0-py36_0
#     snowballstemmer:               1.2.1-py36_0                          --> 2.0.0-py_0
#     soupsieve:                     1.7.1-py36_0                          --> 1.9.3-py36_0
#     sphinx:                        1.8.4-py36_0                          --> 2.2.1-py_0
#     sphinxcontrib-websupport:      1.1.0-py36_1                          --> 1.1.2-py_0
#     spyder:                        3.3.3-py36_0                          --> 3.3.6-py36_0
#     spyder-kernels:                0.4.2-py36_0                          --> 0.5.2-py36_0
#     sqlalchemy:                    1.2.18-py36h7b6447c_0                 --> 1.3.10-py36h7b6447c_0
#     sqlite:                        3.26.0-h7b6447c_0                     --> 3.30.1-h7b6447c_0
#     statsmodels:                   0.9.0-py36h035aef0_0                  --> 0.10.1-py36hdd07704_0
#     sympy:                         1.3-py36_0                            --> 1.4-py36_0
#     tabulate:                      0.8.2-py36_0                          --> 0.8.3-py36_0
#     tblib:                         1.3.2-py36_0                          --> 1.4.0-py_0
#     tensorflow-base:               1.13.1-mkl_py36h7ce6ba3_0             --> 2.0.0-eigen_py36h4ed9498_0
#     tensorflow-estimator:          1.13.0-py_0                           --> 2.0.0-pyh2649769_0
#     terminado:                     0.8.1-py36_1                          --> 0.8.2-py36_0
#     thrift-cpp:                    0.11.0-h02b749d_3                     --> 0.11.0-hc04171f_3
#     toolz:                         0.9.0-py36_0                          --> 0.10.0-py_0
#     tornado:                       5.1.1-py36h7b6447c_0                  --> 6.0.3-py36h7b6447c_0
#     tqdm:                          4.31.1-py36_1                         --> 4.36.1-py_0
#     traitlets:                     4.3.2-py36_0                          --> 4.3.3-py36_0
#     typed-ast:                     1.3.1-py36h7b6447c_0                  --> 1.4.0-py36h7b6447c_0
#     urllib3:                       1.24.1-py36_0                         --> 1.24.2-py36_0
#     werkzeug:                      0.14.1-py36_0                         --> 0.16.0-py_0
#     wheel:                         0.32.3-py36_0                         --> 0.33.6-py36_0
#     widgetsnbextension:            3.4.2-py36_0                          --> 3.5.1-py36_0
#     wrapt:                         1.11.1-py36h7b6447c_0                 --> 1.11.2-py36h7b6447c_0
#     wurlitzer:                     1.0.2-py36_0                          --> 1.0.3-py36_0
#     xlsxwriter:                    1.1.2-py36_0                          --> 1.2.2-py_0
#     zict:                          0.1.3-py36_0                          --> 1.0.0-py_0
#
# The following packages will be DOWNGRADED:
#
#     basemap:                       1.2.0-py36hf62cb97_3      conda-forge --> 1.2.0-py36h705c2d8_0
#     boost-cpp:                     1.68.0-h11c811c_1000      conda-forge --> 1.67.0-h14c3975_4
#     cryptography:                  2.5-py36h1ba5d50_0                    --> 2.3.1-py36hc365091_0
#     curl:                          7.63.0-hbc83047_1000                  --> 7.61.0-h84994c4_0
#     fiona:                         1.8.4-py36heb36068_1001   conda-forge --> 1.7.12-py36h3f37509_0
#     freexl:                        1.0.5-h14c3975_1002       conda-forge --> 1.0.5-h14c3975_0
#     gdal:                          2.3.3-py36hbb2a789_0                  --> 2.2.2-py36hc209d97_1
#     geopandas:                     0.6.1-py_1                conda-forge --> 0.4.1-py_0
#     geos:                          3.7.1-hf484d3e_1000       conda-forge --> 3.6.2-heeff764_2
#     giflib:                        5.1.9-h516909a_0          conda-forge --> 5.1.4-h14c3975_1
#     grpcio:                        1.16.1-py36hf8bcb03_1                 --> 1.14.1-py36h9ba97e2_0
#     h5py:                          2.9.0-py36h7918eee_0                  --> 2.8.0-py36h989c5e5_3
#     hdf5:                          1.10.4-hb1b8bf9_0                     --> 1.10.2-hba1933b_1
#     json-c:                        0.13.1-h14c3975_1001      conda-forge --> 0.13.1-h1bed415_0
#     kealib:                        1.4.10-h1978553_1003      conda-forge --> 1.4.7-h77bc034_6
#     krb5:                          1.16.1-h173b8e3_7                     --> 1.16.1-hc83ff2d_6
#     libarchive:                    3.3.3-h5d8350f_5                      --> 3.3.2-hb43526a_6
#     libcurl:                       7.63.0-h20c2e04_1000                  --> 7.61.0-h1ad7b7a_0
#     libgdal:                       2.3.3-h2e7e64b_0                      --> 2.2.4-h6f639c0_1
#     libkml:                        1.3.0-h328b03d_1009       conda-forge --> 1.3.0-h590aaf7_4
#     libnetcdf:                     4.6.1-h11d0813_2                      --> 4.6.1-h10edf3e_1
#     libpq:                         11.1-h20c2e04_0                       --> 10.5-h1ad7b7a_0
#     libspatialindex:               1.9.3-he1b5a44_1          conda-forge --> 1.8.5-h20b78c2_2
#     libspatialite:                 4.3.0a-hb5ec416_1026      conda-forge --> 4.3.0a-he475c7f_19
#     munch:                         2.5.0-py_0                conda-forge --> 2.3.2-py36_0
#     openjpeg:                      2.3.1-h21c5421_1          conda-forge --> 2.3.0-h05c96fa_1
#     openssl:                       1.1.1c-h516909a_0         conda-forge --> 1.0.2t-h7b6447c_1
#     poppler-data:                  0.4.9-1                   conda-forge --> 0.4.9-0
#     proj4:                         5.2.0-he1b5a44_1006       conda-forge --> 5.0.1-h14c3975_0
#     psycopg2:                      2.7.6.1-py36h1ba5d50_0                --> 2.7.5-py36hb7f436b_0
#     pyproj:                        1.9.6-py36h516909a_1002   conda-forge --> 1.9.5.1-py36h7b21b82_1
#     python:                        3.6.8-h0371630_0                      --> 3.6.6-h6e4f718_2
#     qt:                            5.9.7-h5867ecd_1                      --> 5.9.6-h8703b6f_2
#     rtree:                         0.8.3-py36h7b0cdae_1003   conda-forge --> 0.8.3-py36_0
#     shapely:                       1.6.4-py36h06cd6f9_1005   conda-forge --> 1.6.4-py36h7ef4460_0
#     xerces-c:                      3.2.2-hea5cb30_1003       conda-forge --> 3.2.2-h780794e_0
#
#
# Downloading and Extracting Packages
# pyrsistent-0.15.4    | 92 KB     | ##################################### | 100%
# pytables-3.4.4       | 1.5 MB    | ##################################### | 100%
# pycurl-7.43.0.2      | 60 KB     | ##################################### | 100%
# nltk-3.4.5           | 2.1 MB    | ##################################### | 100%
# openssl-1.0.2t       | 3.1 MB    | ##################################### | 100%
# zipp-0.6.0           | 9 KB      | ##################################### | 100%
# scikit-learn-0.21.3  | 6.8 MB    | ##################################### | 100%
# spyder-kernels-0.5.2 | 69 KB     | ##################################### | 100%
# jinja2-2.10.3        | 95 KB     | ##################################### | 100%
# tensorflow-base-2.0. | 68.9 MB   | ##################################### | 100%
# lazy-object-proxy-1. | 30 KB     | ##################################### | 100%
# libspatialindex-1.8. | 666 KB    | ##################################### | 100%
# mock-3.0.5           | 47 KB     | ##################################### | 100%
# protobuf-3.9.2       | 701 KB    | ##################################### | 100%
# numpy-base-1.17.2    | 5.3 MB    | ##################################### | 100%
# freetds-1.00.97      | 2.4 MB    | ##################################### | 100%
# bitarray-1.0.1       | 60 KB     | ##################################### | 100%
# werkzeug-0.16.0      | 255 KB    | ##################################### | 100%
# pytest-doctestplus-0 | 18 KB     | ##################################### | 100%
# wrapt-1.11.2         | 48 KB     | ##################################### | 100%
# kealib-1.4.7         | 170 KB    | ##################################### | 100%
# freexl-1.0.5         | 44 KB     | ##################################### | 100%
# libpq-10.5           | 2.7 MB    | ##################################### | 100%
# nbconvert-5.6.0      | 494 KB    | ##################################### | 100%
# markupsafe-1.1.1     | 29 KB     | ##################################### | 100%
# libevent-2.1.8       | 1.4 MB    | ##################################### | 100%
# dask-core-2.6.0      | 578 KB    | ##################################### | 100%
# tblib-1.4.0          | 14 KB     | ##################################### | 100%
# pathlib2-2.3.5       | 37 KB     | ##################################### | 100%
# basemap-1.2.0        | 15.2 MB   | ##################################### | 100%
# ipykernel-5.1.3      | 167 KB    | ##################################### | 100%
# contextlib2-0.6.0    | 16 KB     | ##################################### | 100%
# ipython-7.9.0        | 1.1 MB    | ##################################### | 100%
# plotly-4.1.1         | 4.0 MB    | ##################################### | 100%
# opt_einsum-3.1.0     | 54 KB     | ##################################### | 100%
# markdown-3.1.1       | 113 KB    | ##################################### | 100%
# pytest-openfiles-0.4 | 10 KB     | ##################################### | 100%
# mkl_fft-1.0.14       | 173 KB    | ##################################### | 100%
# libspatialite-4.3.0a | 3.1 MB    | ##################################### | 100%
# py-1.8.0             | 66 KB     | ##################################### | 100%
# typed-ast-1.4.0      | 208 KB    | ##################################### | 100%
# scikit-image-0.15.0  | 28.4 MB   | ##################################### | 100%
# cryptography-2.3.1   | 585 KB    | ##################################### | 100%
# sphinxcontrib-htmlhe | 28 KB     | ##################################### | 100%
# biopython-1.74       | 2.5 MB    | ##################################### | 100%
# dbus-1.13.12         | 611 KB    | ##################################### | 100%
# packaging-19.2       | 30 KB     | ##################################### | 100%
# pcre-8.43            | 260 KB    | ##################################### | 100%
# libprotobuf-3.9.2    | 4.7 MB    | ##################################### | 100%
# hdf4-4.2.13          | 916 KB    | ##################################### | 100%
# asn1crypto-1.2.0     | 162 KB    | ##################################### | 100%
# rope-0.14.0          | 113 KB    | ##################################### | 100%
# cython-0.29.13       | 2.2 MB    | ##################################### | 100%
# pyflakes-2.1.1       | 105 KB    | ##################################### | 100%
# hdf5-1.10.2          | 5.2 MB    | ##################################### | 100%
# poppler-data-0.4.9   | 3.5 MB    | ##################################### | 100%
# jupyter_core-4.6.0   | 74 KB     | ##################################### | 100%
# scipy-1.3.1          | 18.1 MB   | ##################################### | 100%
# attrs-19.3.0         | 39 KB     | ##################################### | 100%
# tqdm-4.36.1          | 50 KB     | ##################################### | 100%
# qt-5.9.6             | 87.1 MB   | ##################################### | 100%
# jdcal-1.4.1          | 11 KB     | ##################################### | 100%
# decorator-4.4.1      | 13 KB     | ##################################### | 100%
# ca-certificates-2019 | 131 KB    | ##################################### | 100%
# lxml-4.4.1           | 1.6 MB    | ##################################### | 100%
# parso-0.5.1          | 68 KB     | ##################################### | 100%
# wurlitzer-1.0.3      | 14 KB     | ##################################### | 100%
# pixman-0.38.0        | 618 KB    | ##################################### | 100%
# secretstorage-3.1.1  | 24 KB     | ##################################### | 100%
# snowballstemmer-2.0. | 58 KB     | ##################################### | 100%
# importlib_metadata-0 | 43 KB     | ##################################### | 100%
# sphinxcontrib-devhel | 23 KB     | ##################################### | 100%
# py-xgboost-0.90      | 77 KB     | ##################################### | 100%
# mkl_random-1.1.0     | 369 KB    | ##################################### | 100%
# qtpy-1.9.0           | 39 KB     | ##################################### | 100%
# qtconsole-4.5.5      | 94 KB     | ##################################### | 100%
# notebook-6.0.1       | 6.0 MB    | ##################################### | 100%
# xlsxwriter-1.2.2     | 106 KB    | ##################################### | 100%
# libkml-1.3.0         | 633 KB    | ##################################### | 100%
# munch-2.3.2          | 13 KB     | ##################################### | 100%
# pluggy-0.13.0        | 31 KB     | ##################################### | 100%
# cloudpickle-1.2.2    | 29 KB     | ##################################### | 100%
# ipywidgets-7.5.1     | 107 KB    | ##################################### | 100%
# descartes-1.1.0      | 9 KB      | ##################################### | 100%
# numexpr-2.7.0        | 196 KB    | ##################################### | 100%
# soupsieve-1.9.3      | 60 KB     | ##################################### | 100%
# llvmlite-0.30.0      | 17.7 MB   | ##################################### | 100%
# qtawesome-0.6.0      | 671 KB    | ##################################### | 100%
# numba-0.46.0         | 3.2 MB    | ##################################### | 100%
# setuptools-41.6.0    | 650 KB    | ##################################### | 100%
# toolz-0.10.0         | 50 KB     | ##################################### | 100%
# mkl-2019.4           | 204.1 MB  | ##################################### | 100%
# isort-4.3.21         | 68 KB     | ##################################### | 100%
# urllib3-1.24.2       | 153 KB    | ##################################### | 100%
# sphinx-2.2.1         | 1.4 MB    | ##################################### | 100%
# bzip2-1.0.8          | 105 KB    | ##################################### | 100%
# libssh2-1.8.0        | 243 KB    | ##################################### | 100%
# beautifulsoup4-4.8.1 | 153 KB    | ##################################### | 100%
# pytest-5.0.1         | 353 KB    | ##################################### | 100%
# certifi-2019.9.11    | 154 KB    | ##################################### | 100%
# tabulate-0.8.3       | 39 KB     | ##################################### | 100%
# networkx-2.4         | 1.2 MB    | ##################################### | 100%
# json5-0.8.5          | 25 KB     | ##################################### | 100%
# python-3.6.6         | 28.9 MB   | ##################################### | 100%
# cytoolz-0.10.0       | 439 KB    | ##################################### | 100%
# itsdangerous-1.1.0   | 17 KB     | ##################################### | 100%
# alabaster-0.7.12     | 16 KB     | ##################################### | 100%
# astroid-2.3.2        | 283 KB    | ##################################### | 100%
# astor-0.8.0          | 45 KB     | ##################################### | 100%
# sqlite-3.30.1        | 1.9 MB    | ##################################### | 100%
# matplotlib-3.1.1     | 6.7 MB    | ##################################### | 100%
# numpydoc-0.9.1       | 31 KB     | ##################################### | 100%
# jeepney-0.4.1        | 21 KB     | ##################################### | 100%
# flask-cors-3.0.8     | 17 KB     | ##################################### | 100%
# pyparsing-2.4.2      | 61 KB     | ##################################### | 100%
# more-itertools-7.2.0 | 99 KB     | ##################################### | 100%
# widgetsnbextension-3 | 1.8 MB    | ##################################### | 100%
# filelock-3.0.12      | 12 KB     | ##################################### | 100%
# json-c-0.13.1        | 70 KB     | ##################################### | 100%
# prometheus_client-0. | 42 KB     | ##################################### | 100%
# giflib-5.1.4         | 78 KB     | ##################################### | 100%
# fiona-1.7.12         | 704 KB    | ##################################### | 100%
# h5py-2.8.0           | 1.1 MB    | ##################################### | 100%
# pyproj-1.9.5.1       | 64 KB     | ##################################### | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ##################################### | 100%
# cffi-1.13.1          | 224 KB    | ##################################### | 100%
# spyder-3.3.6         | 2.5 MB    | ##################################### | 100%
# libnetcdf-4.6.1      | 1.3 MB    | ##################################### | 100%
# grpcio-1.14.1        | 1.0 MB    | ##################################### | 100%
# keras-applications-1 | 33 KB     | ##################################### | 100%
# jedi-0.15.1          | 721 KB    | ##################################### | 100%
# colorama-0.4.1       | 17 KB     | ##################################### | 100%
# jmespath-0.9.4       | 22 KB     | ##################################### | 100%
# pbr-5.4.3            | 78 KB     | ##################################### | 100%
# cligj-0.5.0          | 12 KB     | ##################################### | 100%
# keras-preprocessing- | 36 KB     | ##################################### | 100%
# pip-19.3.1           | 1.9 MB    | ##################################### | 100%
# python-dateutil-2.8. | 281 KB    | ##################################### | 100%
# heapdict-1.0.1       | 9 KB      | ##################################### | 100%
# krb5-1.16.1          | 1.4 MB    | ##################################### | 100%
# jupyterlab-1.1.4     | 11.7 MB   | ##################################### | 100%
# pyzmq-18.1.0         | 520 KB    | ##################################### | 100%
# flask-1.1.1          | 73 KB     | ##################################### | 100%
# libgdal-2.2.4        | 16.1 MB   | ##################################### | 100%
# glob2-0.7            | 14 KB     | ##################################### | 100%
# tensorflow-estimator | 272 KB    | ##################################### | 100%
# boto3-1.9.234        | 91 KB     | ##################################### | 100%
# imagesize-1.1.0      | 8 KB      | ##################################### | 100%
# pyyaml-5.1.2         | 189 KB    | ##################################### | 100%
# google-pasta-0.1.7   | 41 KB     | ##################################### | 100%
# prompt_toolkit-2.0.1 | 227 KB    | ##################################### | 100%
# anaconda-project-0.8 | 215 KB    | ##################################### | 100%
# absl-py-0.8.0        | 161 KB    | ##################################### | 100%
# jupyter_client-5.3.4 | 136 KB    | ##################################### | 100%
# wheel-0.33.6         | 40 KB     | ##################################### | 100%
# proj4-5.0.1          | 7.0 MB    | ##################################### | 100%
# pyodbc-4.0.27        | 70 KB     | ##################################### | 100%
# mapclassify-2.0.1    | 26 KB     | ##################################### | 100%
# traitlets-4.3.3      | 137 KB    | ##################################### | 100%
# openpyxl-3.0.0       | 157 KB    | ##################################### | 100%
# pexpect-4.7.0        | 82 KB     | ##################################### | 100%
# sphinxcontrib-websup | 35 KB     | ##################################### | 100%
# _low_priority-1.0    | 139 KB    | ##################################### | 100%
# dask-2.6.0           | 12 KB     | ##################################### | 100%
# requests-2.22.0      | 89 KB     | ##################################### | 100%
# statsmodels-0.10.1   | 9.6 MB    | ##################################### | 100%
# partd-1.0.0          | 19 KB     | ##################################### | 100%
# fastcache-1.1.0      | 31 KB     | ##################################### | 100%
# pytest-remotedata-0. | 15 KB     | ##################################### | 100%
# docutils-0.15.2      | 742 KB    | ##################################### | 100%
# jsonschema-3.1.1     | 92 KB     | ##################################### | 100%
# kiwisolver-1.1.0     | 90 KB     | ##################################### | 100%
# xerces-c-3.2.2       | 3.2 MB    | ##################################### | 100%
# psycopg2-2.7.5       | 294 KB    | ##################################### | 100%
# pywavelets-1.1.1     | 4.4 MB    | ##################################### | 100%
# psutil-5.6.3         | 328 KB    | ##################################### | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ##################################### | 100%
# geos-3.6.2           | 1.6 MB    | ##################################### | 100%
# rtree-0.8.3          | 46 KB     | ##################################### | 100%
# boost-cpp-1.67.0     | 11 KB     | ##################################### | 100%
# numpy-1.17.2         | 4 KB      | ##################################### | 100%
# pysocks-1.7.1        | 30 KB     | ##################################### | 100%
# path.py-12.0.1       | 23 KB     | ##################################### | 100%
# imageio-2.6.1        | 3.4 MB    | ##################################### | 100%
# pytz-2019.3          | 231 KB    | ##################################### | 100%
# sqlalchemy-1.3.10    | 1.8 MB    | ##################################### | 100%
# geopandas-0.4.1      | 891 KB    | ##################################### | 100%
# pandas-0.25.2        | 11.4 MB   | ##################################### | 100%
# joblib-0.13.2        | 365 KB    | ##################################### | 100%
# tornado-6.0.3        | 643 KB    | ##################################### | 100%
# sympy-1.4            | 9.7 MB    | ##################################### | 100%
# bokeh-1.3.4          | 4.0 MB    | ##################################### | 100%
# curl-7.61.0          | 141 KB    | ##################################### | 100%
# libxgboost-0.90      | 3.8 MB    | ##################################### | 100%
# click-plugins-1.1.1  | 11 KB     | ##################################### | 100%
# sphinxcontrib-serial | 24 KB     | ##################################### | 100%
# botocore-1.12.234    | 3.4 MB    | ##################################### | 100%
# terminado-0.8.2      | 22 KB     | ##################################### | 100%
# dill-0.3.0           | 116 KB    | ##################################### | 100%
# gdal-2.2.2           | 767 KB    | ##################################### | 100%
# s3transfer-0.2.1     | 96 KB     | ##################################### | 100%
# jupyterlab_server-1. | 26 KB     | ##################################### | 100%
# intel-openmp-2019.4  | 876 KB    | ##################################### | 100%
# libarchive-3.3.2     | 1.5 MB    | ##################################### | 100%
# openjpeg-2.3.0       | 456 KB    | ##################################### | 100%
# babel-2.7.0          | 5.8 MB    | ##################################### | 100%
# mkl-service-2.3.0    | 208 KB    | ##################################### | 100%
# libcurl-7.61.0       | 494 KB    | ##################################### | 100%
# sphinxcontrib-appleh | 29 KB     | ##################################### | 100%
# zict-1.0.0           | 12 KB     | ##################################### | 100%
# shapely-1.6.4        | 326 KB    | ##################################### | 100%
# pylint-2.4.3         | 432 KB    | ##################################### | 100%
# sphinxcontrib-jsmath | 8 KB      | ##################################### | 100%
# cx_oracle-7.2.2      | 181 KB    | ##################################### | 100%
# fsspec-0.5.2         | 46 KB     | ##################################### | 100%
# pillow-6.2.0         | 647 KB    | ##################################### | 100%
# distributed-2.6.0    | 393 KB    | ##################################### | 100%
# thrift-cpp-0.11.0    | 2.3 MB    | ##################################### | 100%
# sphinxcontrib-qthelp | 26 KB     | ##################################### | 100%
# astropy-3.2.2        | 7.1 MB    | ##################################### | 100%
# blosc-1.16.3         | 82 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import io,time, os
import pandas as pd
import numpy as np
import pandana
from pandana.loaders import osm
from bokeh.palettes import brewer
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8e99edb141ef> in <module>
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import pandana
#       5 from pandana.loaders import osm
#       6 from bokeh.palettes import brewer
#
# ModuleNotFoundError: No module named 'pandana'

# %%
# @hidden_cell
storage_creds = {'apikey' : 'rqrlKTO277J6k4N_5X_wpI62WqwslFDxspY7o2Nb6s0A',
                 'iam_serviceid_crn' : 'crn:v1:bluemix:public:cloud-object-storage:global:a/8aa0fa0d4ad4480b8bfdf1c4d79f9442:021a8d33-89af-44aa-b548-e6f14a067d79:bucket:prague-data-set',
                 'auth_ep': 'https://iam.cloud.ibm.com/identity/token',
                 'ep': 'https://s3.private.eu-de.cloud-object-storage.appdomain.cloud',
                 'bucket' : 'prague-data-set'}

# %%
import sys
from ibm_botocore.client import Config
import ibm_boto3

def upload_file(credentials,local_file_name,key): 
    storage = ibm_boto3.client(service_name='s3',
    ibm_api_key_id=credentials['apikey'],
    ibm_service_instance_id=credentials['iam_serviceid_crn'],
    ibm_auth_endpoint=credentials['auth_ep'],
    config=Config(signature_version='oauth'),
    endpoint_url=credentials['ep'])
    
    try:
        res=storage.upload_file(Filename=local_file_name, Bucket=credentials['bucket'],Key=key)
    except Exception as e:
        print(Exception, e)
    else:
        print('File {} Uploaded'.format(local_file_name))
        
def download_file(credentials,local_file_name,key):  
    storage = ibm_boto3.client(service_name='s3',
    ibm_api_key_id=credentials['apikey'],
    ibm_service_instance_id=credentials['iam_serviceid_crn'],
    ibm_auth_endpoint=credentials['auth_ep'],
    config=Config(signature_version='oauth'),
    endpoint_url=credentials['ep'])
    try:
        res= storage.download_file(Bucket=credentials['bucket'],Key=key,Filename=local_file_name)
        return True
    except Exception as e:
        print(Exception, e)
        return False
    else:
        print('File {} Downloaded'.format(local_file_name))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-78d02954bf05> in <module>
#       1 import sys
# ----> 2 from ibm_botocore.client import Config
#       3 import ibm_boto3
#       4
#       5 def upload_file(credentials,local_file_name,key):
#
# ModuleNotFoundError: No module named 'ibm_botocore'

# %%
from shapely.geometry import Polygon

def read_coordinates_from_str(input_values):
    splitted  = input_values[1:-1].split('],')
    result = []
    for i in splitted:
        i = i.replace('[', '')
        i = i.replace(' ', '')
        i = i.replace(']', '')
        v = i.split(',')
        v1 = float(v[0])
        v2 = float(v[1])
        result.append([v1,v2])
    
    return result

# %%
def get_bounding_box(polygons):
    i = 0
    for poly in polygons:
        x, y = poly.exterior.coords.xy
        c_min_x = min(x)
        c_max_x = max(x)
        c_min_y = min(y)
        c_max_y = max(y)
        if i == 0:
            min_x = c_min_x
            max_x = c_max_x
            min_y = c_min_y
            max_y = c_max_y
        else:
            if c_min_x < min_x:
                min_x = c_min_x
            if c_max_x > max_x:
                max_x = c_max_x
            if c_min_y < min_y:
                min_y = c_min_y
            if c_max_y > max_y:
                max_y = c_max_y    
        i+=1
    
    return (min_x, min_y, max_x, max_y)

# %%
#defime constants
districts = ['praha 4']
amenities = ['school','sport']

distance = 2000
num_pois = 5
num_categories = len(amenities) + 1 


cbar_kwargs = {}

bmap_kwargs = {}

bgcolor = '#014636'

# keyword arguments to pass for hex bin plots
hex_plot_kwargs = {'gridsize':40,
                   'alpha':0.9, 
                   'cmap':'PuBuGn_r', 
                   'edgecolor':'none'}

files = {'districts':'prague_district_population.csv', 'poi':'prague_pois.csv'}

# %% [markdown]
# Load datasets collected on step 1

# %%
poi_file_name = files['poi']
download_file(storage_creds, poi_file_name,poi_file_name)
df_parague_poi = pd.read_csv(poi_file_name)

population_file_name = files['districts']
download_file(storage_creds, population_file_name, population_file_name)
df_prague_population = pd.read_csv(population_file_name)

df_prague_population.loc[:,'Polygon'] = df_prague_population.loc[:,'Geometry'].apply(lambda x: Polygon(read_coordinates_from_str(x)))
df_prague_population.drop(columns = ['Geometry'], inplace=True)
df_prague_population.rename(columns ={'Polygon':'Geometry'}, inplace=True)

# %% [markdown]
# ## Pedestrian accesabilty map

# %%
if len(districts) > 0:
    print('Getting POIs for: {}'.format(','.join([str(x) for x in districts])))
    selected_pois = df_parague_poi.loc[df_parague_poi.District_Name.isin(districts)]
else:
    selected_pois = df_parague_poi

if len(amenities) > 0:
    print('Getting POIs types: {}'.format(','.join([str(x) for x in amenities])))
    selected_pois = selected_pois.loc[selected_pois.Type.isin(amenities)]
# Out:
# Getting POIs for: praha 4
# Getting POIs types: school,sport

# %%
bbox = get_bounding_box(df_prague_population['Geometry'])
bbox_string = '_'.join([str(x) for x in bbox])
net_filename = 'network_{}.h5'.format(bbox_string)

print('Selected region bounding box is {}'.format(','.join([str(x) for x in bbox])) )

bbox_aspect_ratio = (bbox[2] - bbox[0]) / (bbox[3] - bbox[1])

if download_file(storage_creds,net_filename,net_filename):
    print("Load network form storage")
    network = pandana.network.Network.from_hdf5(net_filename)
else:
    print("Build new network form storage")
    network = osm.pdna_network_from_bbox(bbox[3], bbox[2], bbox[1], bbox[0],network_type='walk')
    print ('Remove low-connectivity nodes and save to h5')
    lcn = network.low_connectivity_nodes(impedance=1000, count=10, imp_name='distance')
    network.save_hdf5(net_filename, rm_nodes=lcn)
    upload_file(storage_creds,net_filename,net_filename)
# Out:
# Selected region bounding box is 14.224437012000067,49.94190007000003,14.706787572000053,50.17742967400005
# Build new network form storage
# Requesting network data within bounding box from Overpass API in 1 request(s)
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](49.94190007,14.22443701,50.17742967,14.70678757);>;);out;'}"
# Downloaded 64,544.4KB from www.overpass-api.de in 4.32 seconds
# Downloaded OSM network data within bounding box from Overpass API in 1 request(s) and 6.19 seconds
# Returning OSM data with 426,565 nodes and 110,645 ways...
# Edge node pairs completed. Took 219.23 seconds
# Returning processed graph with 140,822 nodes and 204,575 edges...
# Completed OSM data download and Pandana node and edge table creation in 238.46 seconds
# Remove low-connectivity nodes and save to h5
# File network_14.224437012000067_49.94190007000003_14.706787572000053_50.17742967400005.h5 Uploaded

# %%
network.precompute(distance + 1)

# %%
network.init_pois(num_categories=num_categories, max_dist=distance, max_pois=num_pois)
shools =  selected_pois[selected_pois.Type == 'school']
network.set_pois(category='school', x_col=shools['longitude'], y_col=shools['latitude'])
sport =  selected_pois[selected_pois.Type == 'sport']
network.set_pois(category='sport', x_col=sport['longitude'], y_col=sport['latitude'])

school_access = network.nearest_pois(distance=distance, category='school', num_pois=num_pois)

print('{:,} nodes'.format(len(school_access)))
school_access.head()

# %%
sport_access = network.nearest_pois(distance=distance, category='sport', num_pois=num_pois)
sport_access.head()

# %%
df_access = school_access.join(sport_access,lsuffix='_shool', rsuffix='_sport')

# %%
df_access.head()

# %%
pois_filename = 'pois_{}.csv'.format(bbox_string)
df_access.to_csv(pois_filename)
upload_file(storage_creds, pois_filename, pois_filename)

# %%
fig_kwargs = {'facecolor':'w', 
              'figsize':(14, 14 * bbox_aspect_ratio )}

plot_kwargs = {'s':5, 
               'alpha':1, 
               'cmap':'PuBuGn_r', 
               'edgecolor':'none'}

n = 3
bmp, fig, ax = network.plot(school_access[n],plot_kwargs=plot_kwargs,  fig_kwargs=fig_kwargs, bmap_kwargs=bmap_kwargs, cbar_kwargs=cbar_kwargs)

ax.set_title('Walking distance (m) to nearest school around Praha 4', fontsize=15)
fig.savefig('accessibility-schhol-4.png', dpi=200, bbox_inches='tight')
upload_file(storage_creds,'accessibility-schhol-4.png','accessibility-schhol-4.png')

# %% [markdown]
# ## Clastering

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

df_edjes = df_access
sil_coeffs = []

for n in range(10):
    alg = AgglomerativeClustering(n_clusters=n, affinity='euclidean', linkage='ward')
    clu = alg.fit_predict(df_coorimates.values)
    sil_coeff = silhouette_score(df_edjes, clu, metric='euclidean')
    sil_coeffs.append(sil_coeff)
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(n_cluster, sil_coeff))

# %%
df_coorimates.insert(0, 'Cluster Labels', clu)

# %%
df_coorimates.groupby('Cluster Labels').mean()

# %%
bmp, fig, ax = network.plot(df_coorimates['Cluster Labels'],plot_kwargs=plot_kwargs,  fig_kwargs=fig_kwargs, bmap_kwargs=bmap_kwargs, cbar_kwargs=cbar_kwargs)

ax.set_title('Clusters', fontsize=15)
fig.savefig('accessibility-schhol-4.png', dpi=200, bbox_inches='tight')
upload_file(storage_creds,'accessibility-schhol-4.png','accessibility-schhol-4.png')
